# %%
# %sql
CREATE TABLE IF NOT EXISTS employee_table (emp_id INT, salary INT, name string);
INSERT INTO employee_table
values (1,1000,"Sam"),
       (2,2000,"Jimmy"),
       (3,3000,"Neel"),
       (4,4000,"Willy"),
       (5,5000,"Scott");
SELECT * FROM employee_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>salary</th><th>name</th></tr></thead><tbody><tr><td>2</td><td>2000</td><td>Jimmy</td></tr><tr><td>4</td><td>4000</td><td>Willy</td></tr><tr><td>5</td><td>5000</td><td>Scott</td></tr><tr><td>3</td><td>3000</td><td>Neel</td></tr><tr><td>1</td><td>1000</td><td>Sam</td></tr></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ${employee_table}_default_location;
CREATE SCHEMA IF NOT EXISTS ${employee_table}_custom_location LOCATION '${da.paths.working_dir}/_custom_location.db';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE SCHEMA EXTENDED ${employee_table}_default_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Namespace Name</td><td>_default_location</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/_default_location.db</td></tr><tr><td>Owner</td><td>root</td></tr><tr><td>Properties</td><td></td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE SCHEMA EXTENDED ${employee_table}_custom_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Namespace Name</td><td>_custom_location</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Location</td><td>dbfs:/_custom_location.db</td></tr><tr><td>Owner</td><td>root</td></tr><tr><td>Properties</td><td></td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE DETAIL employee_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>198bfb40-8279-4869-8344-2bd06c65feac</td><td>default.employee_table</td><td>null</td><td>dbfs:/user/hive/warehouse/employee_table</td><td>2022-09-06T05:11:04.053+0000</td><td>2022-09-06T05:11:18.000+0000</td><td>List()</td><td>5</td><td>5268</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
DROP TABLE employee_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE View Employee_view
     AS SELECT emp_id, name
     FROM employee_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from Employee_view
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th></tr></thead><tbody><tr><td>2</td><td>Jimmy</td></tr><tr><td>4</td><td>Willy</td></tr><tr><td>5</td><td>Scott</td></tr><tr><td>3</td><td>Neel</td></tr><tr><td>1</td><td>Sam</td></tr></tbody></table></div>

# %%
# %sql
CREATE TEMPORARY VIEW temp_view_salary_2000
AS SELECT * FROM employee_table WHERE salary > 2000 ORDER BY salary ASC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM temp_view_salary_2000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>salary</th><th>name</th></tr></thead><tbody><tr><td>3</td><td>3000</td><td>Neel</td></tr><tr><td>4</td><td>4000</td><td>Willy</td></tr><tr><td>5</td><td>5000</td><td>Scott</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TEMPORARY View temp_product USING CSV OPTIONS (
  path = '/FileStore/tables/DataSet/transaction.csv',
  header = "true"
);

SELECT * FROM temp_product;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_id</th><th>product_id</th><th>userid</th><th>price</th><th>product_description</th></tr></thead><tbody><tr><td>3300101</td><td>1000001</td><td>101</td><td>700</td><td>mouse</td></tr><tr><td>3300102</td><td>1000002</td><td>102</td><td>900</td><td>keyboard</td></tr><tr><td>3300103</td><td>1000003</td><td>103</td><td>34000</td><td>tv</td></tr><tr><td>3300104</td><td>1000004</td><td>101</td><td>35000</td><td>fridge</td></tr><tr><td>3300105</td><td>1000005</td><td>105</td><td>55000</td><td>sofa</td></tr><tr><td>3300106</td><td>1000006</td><td>106</td><td>100</td><td>bed</td></tr><tr><td>3300107</td><td>1000007</td><td>105</td><td>66000</td><td>laptop</td></tr><tr><td>3300108</td><td>1000008</td><td>108</td><td>20000</td><td>phone</td></tr><tr><td>3300109</td><td>1000009</td><td>101</td><td>500</td><td>speaker</td></tr><tr><td>3300110</td><td>1000010</td><td>102</td><td>1000</td><td>chair</td></tr></tbody></table></div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>employee_table</td><td>false</td></tr><tr><td>default</td><td>employee_view</td><td>false</td></tr><tr><td></td><td>temp_product</td><td>true</td></tr><tr><td></td><td>temp_view_salary_2000</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
CREATE GLOBAL TEMPORARY VIEW global_temp_view_price_900
AS SELECT * FROM temp_product WHERE price > 900 ORDER BY price ASC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from global_temp.global_temp_view_price_900
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_id</th><th>product_id</th><th>userid</th><th>price</th><th>product_description</th></tr></thead><tbody><tr><td>3300110</td><td>1000010</td><td>102</td><td>1000</td><td>chair</td></tr><tr><td>3300108</td><td>1000008</td><td>108</td><td>20000</td><td>phone</td></tr><tr><td>3300103</td><td>1000003</td><td>103</td><td>34000</td><td>tv</td></tr><tr><td>3300104</td><td>1000004</td><td>101</td><td>35000</td><td>fridge</td></tr><tr><td>3300105</td><td>1000005</td><td>105</td><td>55000</td><td>sofa</td></tr><tr><td>3300107</td><td>1000007</td><td>105</td><td>66000</td><td>laptop</td></tr></tbody></table></div>

# %%
# %sql
show tables in global_temp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>global_temp</td><td>global_temp_view_price_900</td><td>true</td></tr><tr><td></td><td>temp_product</td><td>true</td></tr><tr><td></td><td>temp_view_salary_2000</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
with product_details(
     total_price,
     Description,
     user_id)
     AS (
     select 
     price,
     product_description,
     userid
     from
     temp_product)
select * from product_details
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_price</th><th>Description</th><th>user_id</th></tr></thead><tbody><tr><td>700</td><td>mouse</td><td>101</td></tr><tr><td>900</td><td>keyboard</td><td>102</td></tr><tr><td>34000</td><td>tv</td><td>103</td></tr><tr><td>35000</td><td>fridge</td><td>101</td></tr><tr><td>55000</td><td>sofa</td><td>105</td></tr><tr><td>100</td><td>bed</td><td>106</td></tr><tr><td>66000</td><td>laptop</td><td>105</td></tr><tr><td>20000</td><td>phone</td><td>108</td></tr><tr><td>500</td><td>speaker</td><td>101</td></tr><tr><td>1000</td><td>chair</td><td>102</td></tr></tbody></table></div>

# %%
# %sql
with product_details(
     total_price,
     Description,
     user_id)
     AS (
     select 
     price,
     product_description,
     userid
     from
     temp_product)
select * from product_details
where total_price > 2000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_price</th><th>Description</th><th>user_id</th></tr></thead><tbody><tr><td>34000</td><td>tv</td><td>103</td></tr><tr><td>35000</td><td>fridge</td><td>101</td></tr><tr><td>55000</td><td>sofa</td><td>105</td></tr><tr><td>66000</td><td>laptop</td><td>105</td></tr><tr><td>20000</td><td>phone</td><td>108</td></tr></tbody></table></div>

# %%
# %sql
Select
     min(total_price) As Minimum_Price
     from(
          with min_price(total_price) As(
          Select 
                price
          from
              temp_product)
          select * from min_price);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Minimum_Price</th></tr></thead><tbody><tr><td>100</td></tr></tbody></table></div>
